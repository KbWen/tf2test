# %%
# show game
import gym
from gym import wrappers

env = gym.make('MountainCar-v0')
print(env.action_space.n)
print(env.observation_space)
print(env.observation_space.high)
print(env.observation_space.low)

env = wrappers.Monitor(env, "./gym-results", force=True)
env.reset()
for _ in range(1000):
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done: break
env.close()
# Out:
# 3
# Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# [0.6  0.07]
# [-1.2  -0.07]

# %%
import tensorflow as tf
import numpy as np
import random
from collections import deque

active_n = env.action_space.n

# log_dir = 'tensorboard'
num_episodes = 300
num_exploration_episodes = 100
max_len_episode = 1000
batch_size = 32
learning_rate = 1e-3
gamma = 1.0
initial_epsilon = 1.0
final_epsilon = 0.012

Qmemory = 20000

class DQNetwork(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(units=32, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(units=32, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(units=active_n)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        return x

    def predict(self, inputs):
        q_values = self(inputs)
        return tf.argmax(q_values, axis=-1)

# %%
if __name__ == '__main__':
    env = gym.make('MountainCar-v0')
    env = wrappers.Monitor(env, "./gym-results", force=True)
    
    model = DQNetwork()
    
#     optimizer = SGD(lr = learning_rate)
#     model.compile(optimizer = optimizer, loss = 'mse')
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
#     summary_writer = tf.summary.create_file_writer(log_dir)
#     tf.summary.trace_on(profiler=True)
    replay_buffer = deque(maxlen=Qmemory)
    epsilon = initial_epsilon
    
    for episode_id in range(num_episodes):
        # total_reward = 0
        state = env.reset()
        
        epsilon = max(
            initial_epsilon * (num_exploration_episodes - episode_id) / num_exploration_episodes,
            final_epsilon)
        
        for t in range(max_len_episode):
            
            env.render()
            
            if random.random() < epsilon:
                action = env.action_space.sample()
            else:
                # get Q value
                action = model.predict(np.expand_dims(state, axis=0)).numpy()
                action = action[0]

            next_state, reward, done, _ = env.step(action)
            
            # how to design your reward
            position, _ = next_state
            reward =  abs(position - (-0.5))
            # reward = -50.0 if done else reward
            # reward = 100* (new_state[0] * 0.01) + 0.5 * new_state[1] * new_state[1]) - (state[0] * 0.01 + 0.5 * state[1] * state[1])) 
            # total_reward += reward
            
            # update state
            replay_buffer.append((state, action, reward, next_state, 1 if done else 0))
            state = next_state

            if done:
                print(f"num {t}, episode {episode_id}, epsilon {epsilon}, score {reward}")
                break

            if len(replay_buffer) >= batch_size:
                batch_state, batch_action, batch_reward, batch_next_state, batch_done = zip(
                    *random.sample(replay_buffer, batch_size))
                
                batch_state, batch_reward, batch_next_state, batch_done = \
                    [np.array(a, dtype=np.float32) for a in [batch_state, batch_reward, batch_next_state, batch_done]]
                
                batch_action = np.array(batch_action, dtype=np.int32)

                # action value function Q
                q_value = model(batch_next_state)
                y = batch_reward + (gamma * tf.reduce_max(q_value, axis=1)) * (1 - batch_done)
                
                with tf.GradientTape() as tape:
                    loss = tf.keras.losses.mean_squared_error(
                        y_true=y,
                        y_pred=tf.reduce_sum(model(batch_state) * tf.one_hot(batch_action, depth=active_n), axis=1)
                    )
                grads = tape.gradient(loss, model.variables)
                optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))
                
#             with summary_writer.as_default():
#                 tf.summary.trace_export(name="model_trace", step=0, profiler_outdir=log_dir)
                
        # if total_reward >= max_reward:
            # agent.save_weights("mountaincar-v0.h5")
            # max_reward = total_reward
            
    env.close()
# Out:
# episode 0, epsilon 1.0, score -50.0
# WARNING:tensorflow:Layer dq_network_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# episode 1, epsilon 0.99, score -50.0
# episode 2, epsilon 0.98, score -50.0
# episode 3, epsilon 0.97, score -50.0
# episode 4, epsilon 0.96, score -50.0
# episode 5, epsilon 0.95, score -50.0
# episode 6, epsilon 0.94, score -50.0
# episode 7, epsilon 0.93, score -50.0
# episode 8, epsilon 0.92, score -50.0
# episode 9, epsilon 0.91, score -50.0
# episode 10, epsilon 0.9, score -50.0
# episode 11, epsilon 0.89, score -50.0
# episode 12, epsilon 0.88, score -50.0
# episode 13, epsilon 0.87, score -50.0
# episode 14, epsilon 0.86, score -50.0
# episode 15, epsilon 0.85, score -50.0
# episode 16, epsilon 0.84, score -50.0
# episode 17, epsilon 0.83, score -50.0
# episode 18, epsilon 0.82, score -50.0
# episode 19, epsilon 0.81, score -50.0
# episode 20, epsilon 0.8, score -50.0
# episode 21, epsilon 0.79, score -50.0
# episode 22, epsilon 0.78, score -50.0
# episode 23, epsilon 0.77, score -50.0
# episode 24, epsilon 0.76, score -50.0
# episode 25, epsilon 0.75, score -50.0
# episode 26, epsilon 0.74, score -50.0
# episode 27, epsilon 0.73, score -50.0
# episode 28, epsilon 0.72, score -50.0
# episode 29, epsilon 0.71, score -50.0
# episode 30, epsilon 0.7, score -50.0
# episode 31, epsilon 0.69, score -50.0
# episode 32, epsilon 0.68, score -50.0
# episode 33, epsilon 0.67, score -50.0
# episode 34, epsilon 0.66, score -50.0
# episode 35, epsilon 0.65, score -50.0
# episode 36, epsilon 0.64, score -50.0
# episode 37, epsilon 0.63, score -50.0
# episode 38, epsilon 0.62, score -50.0
# episode 39, epsilon 0.61, score -50.0
# episode 40, epsilon 0.6, score -50.0
# episode 41, epsilon 0.59, score -50.0
# episode 42, epsilon 0.58, score -50.0
# episode 43, epsilon 0.57, score -50.0
# episode 44, epsilon 0.56, score -50.0
# episode 45, epsilon 0.55, score -50.0
# episode 46, epsilon 0.54, score -50.0
# episode 47, epsilon 0.53, score -50.0
# episode 48, epsilon 0.52, score -50.0
# episode 49, epsilon 0.51, score -50.0
# episode 50, epsilon 0.5, score -50.0
# episode 51, epsilon 0.49, score -50.0
# episode 52, epsilon 0.48, score -50.0
# episode 53, epsilon 0.47, score -50.0
# episode 54, epsilon 0.46, score -50.0
# episode 55, epsilon 0.45, score -50.0
# episode 56, epsilon 0.44, score -50.0
# episode 57, epsilon 0.43, score -50.0
# episode 58, epsilon 0.42, score -50.0
# episode 59, epsilon 0.41, score -50.0
# episode 60, epsilon 0.4, score -50.0
# episode 61, epsilon 0.39, score -50.0
# episode 62, epsilon 0.38, score -50.0
# episode 63, epsilon 0.37, score -50.0
# episode 64, epsilon 0.36, score -50.0
# episode 65, epsilon 0.35, score -50.0
# episode 66, epsilon 0.34, score -50.0
# episode 67, epsilon 0.33, score -50.0
# episode 68, epsilon 0.32, score -50.0
# episode 69, epsilon 0.31, score -50.0
# episode 70, epsilon 0.3, score -50.0
# episode 71, epsilon 0.29, score -50.0
# episode 72, epsilon 0.28, score -50.0
# episode 73, epsilon 0.27, score -50.0
# episode 74, epsilon 0.26, score -50.0
# episode 75, epsilon 0.25, score -50.0
# episode 76, epsilon 0.24, score -50.0
# episode 77, epsilon 0.23, score -50.0
# episode 78, epsilon 0.22, score -50.0
# episode 79, epsilon 0.21, score -50.0
# episode 80, epsilon 0.2, score -50.0
# episode 81, epsilon 0.19, score -50.0
# episode 82, epsilon 0.18, score -50.0
# episode 83, epsilon 0.17, score -50.0
# episode 84, epsilon 0.16, score -50.0
# episode 85, epsilon 0.15, score -50.0
# episode 86, epsilon 0.14, score -50.0
# episode 87, epsilon 0.13, score -50.0
# episode 88, epsilon 0.12, score -50.0
# episode 89, epsilon 0.11, score -50.0
# episode 90, epsilon 0.1, score -50.0
# episode 91, epsilon 0.09, score -50.0
# episode 92, epsilon 0.08, score -50.0
# episode 93, epsilon 0.07, score -50.0
# episode 94, epsilon 0.06, score -50.0
# episode 95, epsilon 0.05, score -50.0
# episode 96, epsilon 0.04, score -50.0
# episode 97, epsilon 0.03, score -50.0
# episode 98, epsilon 0.02, score -50.0
# episode 99, epsilon 0.012, score -50.0
# episode 100, epsilon 0.012, score -50.0
# episode 101, epsilon 0.012, score -50.0
# episode 102, epsilon 0.012, score -50.0
# episode 103, epsilon 0.012, score -50.0
# episode 104, epsilon 0.012, score -50.0
# episode 105, epsilon 0.012, score -50.0
# episode 106, epsilon 0.012, score -50.0
# episode 107, epsilon 0.012, score -50.0
# episode 108, epsilon 0.012, score -50.0
# episode 109, epsilon 0.012, score -50.0
# episode 110, epsilon 0.012, score -50.0
# episode 111, epsilon 0.012, score -50.0
# episode 112, epsilon 0.012, score -50.0
# episode 113, epsilon 0.012, score -50.0
# episode 114, epsilon 0.012, score -50.0
# episode 115, epsilon 0.012, score -50.0
# episode 116, epsilon 0.012, score -50.0
# episode 117, epsilon 0.012, score -50.0
# episode 118, epsilon 0.012, score -50.0
# episode 119, epsilon 0.012, score -50.0
# episode 120, epsilon 0.012, score -50.0
# episode 121, epsilon 0.012, score -50.0
# episode 122, epsilon 0.012, score -50.0
# episode 123, epsilon 0.012, score -50.0
# episode 124, epsilon 0.012, score -50.0
# episode 125, epsilon 0.012, score -50.0
# episode 126, epsilon 0.012, score -50.0
# episode 127, epsilon 0.012, score -50.0
# episode 128, epsilon 0.012, score -50.0
# episode 129, epsilon 0.012, score -50.0
# episode 130, epsilon 0.012, score -50.0
# episode 131, epsilon 0.012, score -50.0
# episode 132, epsilon 0.012, score -50.0
# episode 133, epsilon 0.012, score -50.0
# episode 134, epsilon 0.012, score -50.0
# episode 135, epsilon 0.012, score -50.0
# episode 136, epsilon 0.012, score -50.0
# episode 137, epsilon 0.012, score -50.0
# episode 138, epsilon 0.012, score -50.0
# episode 139, epsilon 0.012, score -50.0
# episode 140, epsilon 0.012, score -50.0
# episode 141, epsilon 0.012, score -50.0
# episode 142, epsilon 0.012, score -50.0
# episode 143, epsilon 0.012, score -50.0
# episode 144, epsilon 0.012, score -50.0
# episode 145, epsilon 0.012, score -50.0
# episode 146, epsilon 0.012, score -50.0
# episode 147, epsilon 0.012, score -50.0
# episode 148, epsilon 0.012, score -50.0
# episode 149, epsilon 0.012, score -50.0
# episode 150, epsilon 0.012, score -50.0
# episode 151, epsilon 0.012, score -50.0
# episode 152, epsilon 0.012, score -50.0
# episode 153, epsilon 0.012, score -50.0
# episode 154, epsilon 0.012, score -50.0
# episode 155, epsilon 0.012, score -50.0
# episode 156, epsilon 0.012, score -50.0
# episode 157, epsilon 0.012, score -50.0
# episode 158, epsilon 0.012, score -50.0
# episode 159, epsilon 0.012, score -50.0
# episode 160, epsilon 0.012, score -50.0
# episode 161, epsilon 0.012, score -50.0
# episode 162, epsilon 0.012, score -50.0
# episode 163, epsilon 0.012, score -50.0
# episode 164, epsilon 0.012, score -50.0
# episode 165, epsilon 0.012, score -50.0
# episode 166, epsilon 0.012, score -50.0
# episode 167, epsilon 0.012, score -50.0
# episode 168, epsilon 0.012, score -50.0
# episode 169, epsilon 0.012, score -50.0
# episode 170, epsilon 0.012, score -50.0
# episode 171, epsilon 0.012, score -50.0
# episode 172, epsilon 0.012, score -50.0
# episode 173, epsilon 0.012, score -50.0
# episode 174, epsilon 0.012, score -50.0
# episode 175, epsilon 0.012, score -50.0
# episode 176, epsilon 0.012, score -50.0
# episode 177, epsilon 0.012, score -50.0
# episode 178, epsilon 0.012, score -50.0
# episode 179, epsilon 0.012, score -50.0
# episode 180, epsilon 0.012, score -50.0
# episode 181, epsilon 0.012, score -50.0
# episode 182, epsilon 0.012, score -50.0
# episode 183, epsilon 0.012, score -50.0
# episode 184, epsilon 0.012, score -50.0
# episode 185, epsilon 0.012, score -50.0
# episode 186, epsilon 0.012, score -50.0
# episode 187, epsilon 0.012, score -50.0
# episode 188, epsilon 0.012, score -50.0
# episode 189, epsilon 0.012, score -50.0
# episode 190, epsilon 0.012, score -50.0
# episode 191, epsilon 0.012, score -50.0
# episode 192, epsilon 0.012, score -50.0
# episode 193, epsilon 0.012, score -50.0
# episode 194, epsilon 0.012, score -50.0
# episode 195, epsilon 0.012, score -50.0
# episode 196, epsilon 0.012, score -50.0
# episode 197, epsilon 0.012, score -50.0
# episode 198, epsilon 0.012, score -50.0
# episode 199, epsilon 0.012, score -50.0
# episode 200, epsilon 0.012, score -50.0
# episode 201, epsilon 0.012, score -50.0
# episode 202, epsilon 0.012, score -50.0
# episode 203, epsilon 0.012, score -50.0
# episode 204, epsilon 0.012, score -50.0
# episode 205, epsilon 0.012, score -50.0
# episode 206, epsilon 0.012, score -50.0
# episode 207, epsilon 0.012, score -50.0
# episode 208, epsilon 0.012, score -50.0
# episode 209, epsilon 0.012, score -50.0
# episode 210, epsilon 0.012, score -50.0
# episode 211, epsilon 0.012, score -50.0
# episode 212, epsilon 0.012, score -50.0
# episode 213, epsilon 0.012, score -50.0
# episode 214, epsilon 0.012, score -50.0
# episode 215, epsilon 0.012, score -50.0
# episode 216, epsilon 0.012, score -50.0
# episode 217, epsilon 0.012, score -50.0
# episode 218, epsilon 0.012, score -50.0
# episode 219, epsilon 0.012, score -50.0
# episode 220, epsilon 0.012, score -50.0
# episode 221, epsilon 0.012, score -50.0
# episode 222, epsilon 0.012, score -50.0
# episode 223, epsilon 0.012, score -50.0
# episode 224, epsilon 0.012, score -50.0
# episode 225, epsilon 0.012, score -50.0
# episode 226, epsilon 0.012, score -50.0
# episode 227, epsilon 0.012, score -50.0
# episode 228, epsilon 0.012, score -50.0
# episode 229, epsilon 0.012, score -50.0
# episode 230, epsilon 0.012, score -50.0
# episode 231, epsilon 0.012, score -50.0
# episode 232, epsilon 0.012, score -50.0
# episode 233, epsilon 0.012, score -50.0
# episode 234, epsilon 0.012, score -50.0
# episode 235, epsilon 0.012, score -50.0
# episode 236, epsilon 0.012, score -50.0
# episode 237, epsilon 0.012, score -50.0
# episode 238, epsilon 0.012, score -50.0
# episode 239, epsilon 0.012, score -50.0
# episode 240, epsilon 0.012, score -50.0
# episode 241, epsilon 0.012, score -50.0
# episode 242, epsilon 0.012, score -50.0
# episode 243, epsilon 0.012, score -50.0
# episode 244, epsilon 0.012, score -50.0
# episode 245, epsilon 0.012, score -50.0
# episode 246, epsilon 0.012, score -50.0
# episode 247, epsilon 0.012, score -50.0
# episode 248, epsilon 0.012, score -50.0
# episode 249, epsilon 0.012, score -50.0
# episode 250, epsilon 0.012, score -50.0
# episode 251, epsilon 0.012, score -50.0
# episode 252, epsilon 0.012, score -50.0
# episode 253, epsilon 0.012, score -50.0
# episode 254, epsilon 0.012, score -50.0
# episode 255, epsilon 0.012, score -50.0
# episode 256, epsilon 0.012, score -50.0
# episode 257, epsilon 0.012, score -50.0
# episode 258, epsilon 0.012, score -50.0
# episode 259, epsilon 0.012, score -50.0
# episode 260, epsilon 0.012, score -50.0
# episode 261, epsilon 0.012, score -50.0
# episode 262, epsilon 0.012, score -50.0
# episode 263, epsilon 0.012, score -50.0
# episode 264, epsilon 0.012, score -50.0
# episode 265, epsilon 0.012, score -50.0
# episode 266, epsilon 0.012, score -50.0
# episode 267, epsilon 0.012, score -50.0
# episode 268, epsilon 0.012, score -50.0
# episode 269, epsilon 0.012, score -50.0
# episode 270, epsilon 0.012, score -50.0
# episode 271, epsilon 0.012, score -50.0
# episode 272, epsilon 0.012, score -50.0
# episode 273, epsilon 0.012, score -50.0
# episode 274, epsilon 0.012, score -50.0
# episode 275, epsilon 0.012, score -50.0
# episode 276, epsilon 0.012, score -50.0
# episode 277, epsilon 0.012, score -50.0
# episode 278, epsilon 0.012, score -50.0
# episode 279, epsilon 0.012, score -50.0
# episode 280, epsilon 0.012, score -50.0
# episode 281, epsilon 0.012, score -50.0
# episode 282, epsilon 0.012, score -50.0
# episode 283, epsilon 0.012, score -50.0
# episode 284, epsilon 0.012, score -50.0
# episode 285, epsilon 0.012, score -50.0
# episode 286, epsilon 0.012, score -50.0
# episode 287, epsilon 0.012, score -50.0
# episode 288, epsilon 0.012, score -50.0
# episode 289, epsilon 0.012, score -50.0
# episode 290, epsilon 0.012, score -50.0
# episode 291, epsilon 0.012, score -50.0
# episode 292, epsilon 0.012, score -50.0
# episode 293, epsilon 0.012, score -50.0
# episode 294, epsilon 0.012, score -50.0
# episode 295, epsilon 0.012, score -50.0
# episode 296, epsilon 0.012, score -50.0
# episode 297, epsilon 0.012, score -50.0
# episode 298, epsilon 0.012, score -50.0
# episode 299, epsilon 0.012, score -50.0
